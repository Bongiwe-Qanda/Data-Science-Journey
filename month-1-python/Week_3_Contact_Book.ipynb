# %%
contacts = []

def display_contact(contact):
    print("----------------------------")
    print(f"Name:  {contact['name']}")
    print(f"Phone: {contact['phone']}")
    print(f"Email: {contact['email']}")
    print("----------------------------")

def add_contacts(name,phone_number,email):

  contact = {
      "name": name,
      "phone": phone_number,
      "email": email
  }
  contacts.append(contact)
  print(f" {name} added successfully!")

def search_contact(name):
  for contact in contacts:
    if contact["name"] == name:
      print(contact)
      return
  print("You have no contacts.")


def display():

    if len(contacts) == 0:
      print(f"\n All Contacts ({len(contacts)} total)")
      print("No contacts")
    else:
      for contact in contacts:
        display_contact(contact)

def main_menu():
  print("\n====== YOUR CONTACT BOOK ======")
  while True:
    print("======================")
    print("1. Add contact")
    print("2. Search contacts")
    print("3. View all contacts.")
    print("4. Quit")
    option = int(input("Choose an option-->>"))

    if option == 1:
      name = input("Enter name: ")
      phone_number = input("Enter phone number: ")
      email = input("Enter email: ")
      add_contacts(name,phone_number,email)

    elif option == 2:
      name = input("Enter name: ")
      search_contact(name)

    elif option == 3:
      display()

    elif option == 4:
      print("You are done!!")
      break

    else:
      print("Invalid option, try again.")

main_menu()
# Out:
# ====== CONTACT BOOK ======
# ======================
# 1. Add contact
# 2. Search contacts
# 3. View all contacts.
# 4. Quit
# Choose an option-->>1
# Enter name: Bongiwe
# Enter phone number: 087954
# Enter email: bongi@gmail
#  Bongiwe added successfully!
# ======================
# 1. Add contact
# 2. Search contacts
# 3. View all contacts.
# 4. Quit
# Choose an option-->>3
# ----------------------------
# Name:  Bongiwe
# Phone: 087954
# Email: bongi@gmail
# ----------------------------
# ======================
# 1. Add contact
# 2. Search contacts
# 3. View all contacts.
# 4. Quit
# Choose an option-->>2
# Enter name: Bongiwe
# ----------------------------
# Name:  Bongiwe
# Phone: 087954
# Email: bongi@gmail
# ----------------------------
# ======================
# 1. Add contact
# 2. Search contacts
# 3. View all contacts.
# 4. Quit
# Choose an option-->>2
# Enter name: Bongi
# You have no contacts.
# ======================
# 1. Add contact
# 2. Search contacts
# 3. View all contacts.
# 4. Quit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2729/3638030132.py in <cell line: 0>()
#      65       print("Invalid option, try again.")
#      66
# ---> 67 main_menu()
#      68
#
# /tmp/ipykernel_2729/3638030132.py in main_menu()
#      43     print("3. View all contacts.")
#      44     print("4. Quit")
# ---> 45     option = int(input("Choose an option-->>"))
#      46
#      47     if option == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
